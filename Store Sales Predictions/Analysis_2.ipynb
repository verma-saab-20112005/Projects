# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_excel("train.xlsx")

# %%
col= data.columns.tolist()

# %%
for i in range(len(col)):
    if data[col[i]].dtype=="object":
        data[col[i]]= data[col[i]].astype("string")

# %%
for i in range(len(col)):
    if data[col[i]].dtype!="string" and data[col[i]].dtype!="datetime64[ns]":
        data[col[i]]= data[col[i]].astype("int64")

# %%
len(data["Sales"])
# Out:
# 1017209

# %%
data["Sales"].value_counts()
# Out:
# Sales
# 0        172871
# 5674        215
# 5558        197
# 5483        196
# 6049        195
#           ...
# 23861         1
# 22756         1
# 24520         1
# 24144         1
# 24287         1
# Name: count, Length: 21734, dtype: int64

# %%
for i in range(len(data["Sales"])):
    if data["Sales"].iloc[i]==0:
        print(data.iloc
