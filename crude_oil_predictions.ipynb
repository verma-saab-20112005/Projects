# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("commodities_dataset.csv")

# %%
data
# Out:
#             Date  Crude_Oil_WTI_('Close', 'CL=F')  \
# 0     1997-10-29                              NaN
# 1     1997-10-30                              NaN
# 2     1997-10-31                              NaN
# 3     1997-11-03                              NaN
# 4     1997-11-04                              NaN
# ...          ...                              ...
# 7098  2025-12-26                        56.740002
# 7099  2025-12-29                        58.080002
# 7100  2025-12-30                        57.950001
# 7101  2025-12-31                        57.419998
# 7102  2026-01-02                        57.320000
#
#       Crude_Oil_WTI_('High', 'CL=F')  Crude_Oil_WTI_('Low', 'CL=F')  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# ...

# %%
data.describe()
# Out:
#        Crude_Oil_WTI_('Close', 'CL=F')  Crude_Oil_WTI_('High', 'CL=F')  \
# count                      6368.000000                     6368.000000
# mean                         64.662687                       65.668346
# std                          24.584397                       24.839614
# min                         -37.630001                       13.690000
# 25%                          46.317500                       47.267500
# 50%                          63.669998                       64.625000
# 75%                          81.930000                       83.082500
# max                         145.289993                      147.270004
#
#        Crude_Oil_WTI_('Low', 'CL=F')  Crude_Oil_WTI_('Open', 'CL=F')  \
# count                    6368.000000                     6368.000000
# mean                       63.608268                       64.674788
# std                        24.286116                       24.577595
# ...

# %%
col= data.columns.tolist()

# %%
for col_1 in col:
    print(data[col_1].dtype)
# Out:
# object
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# ...

# %%
df= data.drop("Date", axis=1)

# %%
df.corr()
# Out:
#                                   Crude_Oil_WTI_('Close', 'CL=F')  \
# Crude_Oil_WTI_('Close', 'CL=F')                          1.000000
# Crude_Oil_WTI_('High', 'CL=F')                           0.998711
# Crude_Oil_WTI_('Low', 'CL=F')                            0.999199
# Crude_Oil_WTI_('Open', 'CL=F')                           0.997801
# Crude_Oil_WTI_('Volume', 'CL=F')                         0.088759
# ...                                                           ...
# Year                                                     0.323373
# Month                                                   -0.013785
# Quarter                                                 -0.011822
# Day_of_Week                                              0.004798
# Week_of_Year                                            -0.013535
#
#                                   Crude_Oil_WTI_('High', 'CL=F')  \
# Crude_Oil_WTI_('Close', 'CL=F')                         0.998711
# ...
