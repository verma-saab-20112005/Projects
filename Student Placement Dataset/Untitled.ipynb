# %%
import pandas as pd
import numpy as np

# %%
from sklearn.preprocessing import KBinDescritizer as kb
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sklearn.preprocessing import KBinDescritizer as kb
#
# ImportError: cannot import name 'KBinDescritizer' from 'sklearn.preprocessing' (C:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\__init__.py)
