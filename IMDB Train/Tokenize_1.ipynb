# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
tokenizer= Tokenizer(oov_token="nothing")

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index
# Out:
# {'nothing': 1,
#  'india': 2,
#  'jeetega': 3,
#  'hip': 4,
#  'ki': 5,
#  'jai': 6,
#  'kohli': 7,
#  'sachin': 8,
#  'dhoni': 9,
#  'go': 10,
#  'hurray': 11,
#  'bhai': 12,
#  'bharat': 13,
#  'mata': 14,
#  'modi': 15,
#  'ji': 16,
#  'inquilab': 17,
#  'zindabad': 18}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('go', 1),
#              ('india', 4),
#              ('hip', 2),
#              ('hurray', 1),
#              ('jeetega', 3),
#              ('bhai', 1),
#              ('bharat', 1),
#              ('mata', 1),
#              ('ki', 2),
#              ('jai', 2),
#              ('kohli', 2),
#              ('sachin', 2),
#              ('dhoni', 2),
#              ('modi', 1),
#              ('ji', 1),
#              ('inquilab', 1),
#              ('zindabad', 1)])

# %%
tokenizer.document_count
# Out:
# 10

# %%
len(docs)
# Out:
# 10

# %%
sequences= tokenizer.texts_to_sequences(docs)

# %%
sequences
# Out:
# [[10, 2],
#  [2, 2],
#  [4, 4, 11],
#  [3, 12, 3, 2, 3],
#  [13, 14, 5, 6],
#  [7, 7],
#  [8, 8],
#  [9, 9],
#  [15, 16, 5, 6],
#  [17, 18]]

# %%
from keras.utils import pad_sequences

# %%
sequences= pad_sequences(sequences, padding="post")

# %%
sequences
# Out:
# array([[10,  2,  0,  0,  0],
#        [ 2,  2,  0,  0,  0],
#        [ 4,  4, 11,  0,  0],
#        [ 3, 12,  3,  2,  3],
#        [13, 14,  5,  6,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [ 9,  9,  0,  0,  0],
#        [15, 16,  5,  6,  0],
#        [17, 18,  0,  0,  0]], dtype=int32)

# %%
tokenizer1= Tokenizer()

# %%
tokenizer1.fit_on_texts(docs)

# %%
len(tokenizer1.word_index)
# Out:
# 17

# %%
sequences1= tokenizer1.texts_to_sequences(docs)

# %%
sequences1= pad_sequences(sequences1, padding="post")

# %%
len(sequences1[0])
# Out:
# 5

# %%
from keras.layers import Dense, SimpleRNN, Embedding, Dropout, BatchNormalization, Input, Flatten
from keras.models import Sequential
from keras.regularizers import L2
from keras.callbacks import EarlyStopping

# %%
model= Sequential([
    Input(shape=(5,)),
    Embedding(input_dim=17, output_dim=2),
    SimpleRNN(64, return_sequences=False),
    Dense(32, activation="relu", kernel_regularizer=L2(0.001)),
    Dense(8, activation="relu", kernel_regularizer=L2(0.001)),
    Dense(1, activation="sigmoid")
])

# %%
model.compile(
    optimizer="Adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
predictions= model.predict(sequences)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 predictions= model.predict(sequences)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ...
