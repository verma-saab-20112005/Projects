# %%
import pandas as pd
import numpy as np

# %%
import tensorflow as tf
import keras

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
from keras.datasets import imdb

# %%
(x_train, y_train), (x_test, y_test)= imdb.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
len(x_train[0])
# Out:
# 218

# %%
from keras.utils import pad_sequences

# %%
x_train= pad_sequences(x_train, padding="post", maxlen=218)
x_test= pad_sequences(x_test, padding="post", maxlen=218)

# %%
x_test.shape, x_train.shape
# Out:
# ((25000, 218), (25000, 218))

# %%
from keras.layers import Dense, SimpleRNN, Dropout, BatchNormalization, Input
from keras.models import Sequential

# %%
model= Sequential([
    Input(shape=(218,1)),
    SimpleRNN(128, return_sequences=False),
    Dense(8, activation="relu"),
    Dense(1, activation="sigmoid")
])

# %%
model.compile(
    optimizer="Adam",
    loss= "binary_crossentropy",
    metrics=["accuracy"]
)

# %%
model.fit(x_train, y_train, epochs=25, validation_data=(x_test, y_test))
# Out:
# Epoch 1/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.5000 - loss: 0.6979 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 2/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.4956 - loss: 0.6932 - val_accuracy: 0.5001 - val_loss: 0.6931
# Epoch 3/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.5010 - loss: 0.6932 - val_accuracy: 0.5001 - val_loss: 0.6931
# Epoch 4/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.4995 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 5/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4392s 6s/step - accuracy: 0.5021 - loss: 0.6931 - val_accuracy: 0.5001 - val_loss: 0.6932
# Epoch 6/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.4942 - loss: 0.6932 - val_accuracy: 0.5001 - val_loss: 0.6931
# Epoch 7/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4979 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 8/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.4975 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 9/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.5004 - loss: 0.6932 - val_accuracy: 0.5001 - val_loss: 0.6931
# Epoch 10/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4949 - loss: 0.6932 - val_accuracy: 0.5001 - val_loss: 0.6931
# Epoch 11/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.5009 - loss: 0.6931 - val_accuracy: 0.5001 - val_loss: 0.6931
# Epoch 12/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.4959 - loss: 0.6932 - val_accuracy: 0.5001 - val_loss: 0.6931
# Epoch 13/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4942 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 14/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4992 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 15/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4929 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 16/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4984 - loss: 0.6931 - val_accuracy: 0.4999 - val_loss: 0.6931
# Epoch 17/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4979 - loss: 0.6932 - val_accuracy: 0.5001 - val_loss: 0.6931
# Epoch 18/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4979 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 19/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4970 - loss: 0.6932 - val_accuracy: 0.5001 - val_loss: 0.6931
# Epoch 20/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.5004 - loss: 0.6931 - val_accuracy: 0.4999 - val_loss: 0.6931
# Epoch 21/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 49ms/step - accuracy: 0.4994 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 22/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 60ms/step - accuracy: 0.4980 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 23/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 60ms/step - accuracy: 0.4991 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 24/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 79ms/step - accuracy: 0.4947 - loss: 0.6932 - val_accuracy: 0.5001 - val_loss: 0.6931
# Epoch 25/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.4981 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931

# %%
import matplotlib.pyplot as plt

# %%
tokenizer= Tokenizer()
